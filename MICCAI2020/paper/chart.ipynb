# %%
import numpy as np
import matplotlib.pyplot as plt

x = [5,10,15,20]
plt.figure(figsize=(12,8))

# 1
plt.subplot(2, 3, 1)
lsh = plt.plot(x,[0.3265,0.3198,0.3123,0.3070],'b-v',label='LSH')
dpsh = plt.plot(x,[0.4368,0.4080,0.3876,0.3766],'g-v',label='DPSH')
dsh = plt.plot(x,[0.5391,0.4312,0.3778,0.3490],'k-v',label='DSH')
drh = plt.plot(x,[0.6628,0.6050,0.5686,0.5402],'y-v',label='DRH')
ash = plt.plot(x,[0.8288,0.7561,0.6950,0.6544],'r-^',label='ASH')
plt.xticks(x)
plt.ylabel('ASOCT-Cataract')
plt.title('mHR')
plt.legend()
# 2
plt.subplot(2, 3, 2)
lsh = plt.plot(x,[0.2206,0.2146,0.2061,0.2006],'b-v',label='LSH')
dpsh = plt.plot(x,[0.3368,0.2785,0.2462,0.2262],'g-v',label='DPSH')
dsh = plt.plot(x,[0.4950,0.3583,0.2888,0.2476],'k-v',label='DSH')
drh = plt.plot(x,[0.5920,0.5023,0.4477,0.4099],'y-v',label='DRH')
ash = plt.plot(x,[0.7985,0.7000,0.6240,0.5706],'r-^',label='DSH')
plt.xticks(x)
plt.title('mAP')
plt.legend()
# 3
plt.subplot(2, 3, 3)
lsh = plt.plot(x,[0.6379,0.5789,0.5603,0.5499],'b-v',label='LSH')
dpsh = plt.plot(x,[0.7276,0.6774,0.6688,0.6636],'g-v',label='DPSH')
dsh = plt.plot(x,[0.8994,0.8532,0.8317,0.8238],'k-v',label='DSH')
drh = plt.plot(x,[0.8735,0.8479,0.8436,0.8413],'y-v',label='DRH')
ash = plt.plot(x,[0.9635,0.9563,0.9551,0.9525],'r-^',label='ASH')
plt.xticks(x)
plt.title('mRR')
plt.legend()
# 4
plt.subplot(2, 3, 4)
lsh = plt.plot(x,[0.4676,0.4624,0.4609,0.4612],'b-v',label='LSH')
dpsh = plt.plot(x,[0.6128,0.6188,0.6170,0.6178],'g-v',label='DPSH')
dsh = plt.plot(x,[0.6380,0.6331,0.6345,0.6352],'k-v',label='DSH')
drh = plt.plot(x,[0.6490,0.6392,0.6395,0.6418],'y-v',label='DRH')
ash = plt.plot(x,[0.6970,0.6977,0.6964,0.6968],'r-^',label='ASH')
plt.xticks(x)
plt.ylabel('Fundus-iSee')
plt.title('mHR')
plt.legend()
# 5
plt.subplot(2, 3, 5)
lsh = plt.plot(x,[0.3986,0.3828,0.3715,0.3654],'b-v',label='LSH')
dpsh = plt.plot(x,[0.5362,0.5154,0.5034,0.4983],'g-v',label='DPSH')
dsh = plt.plot(x,[0.5664,0.5399,0.5301,0.5253],'k-v',label='DSH')
drh = plt.plot(x,[0.5716,0.5428,0.5326,0.5288],'y-v',label='DRH')
ash = plt.plot(x,[0.6490,0.6346,0.6272,0.6233],'r-^',label='ASH')
plt.xticks(x)
plt.title('mAP')
plt.legend()
# 6
plt.subplot(2, 3, 6)
lsh = plt.plot(x,[0.6882,0.6455,0.6293,0.6118],'b-v',label='LSH')
dpsh = plt.plot(x,[0.8576,0.8229,0.7928,0.7809],'g-v',label='DPSH')
dsh = plt.plot(x,[0.8666,0.8341,0.7992,0.7879],'k-v',label='DSH')
drh = plt.plot(x,[0.8525,0.8243,0.7986,0.7883],'y-v',label='DRH')
ash = plt.plot(x,[0.8986,0.8707,0.8600,0.8429],'r-^',label='ASH')
plt.xticks(x)
plt.title('mRR')
plt.legend()


plt.legend()
plt.show()

# %%
import numpy as np
import matplotlib.pyplot as plt

x = [12,24,36,48]
plt.figure(figsize=(12,8))

# 1
plt.subplot(2, 3, 1)
lsh = plt.plot(x,[0.3198,0.2217,0.2817,0.2284],'b-v',label='LSH')
dpsh = plt.plot(x,[0.4080,0.3202,0.3235,0.3390],'g-v',label='DPSH')
dsh = plt.plot(x,[0.4312,0.3844,0.4621,0.4100],'k-v',label='DSH')
drh = plt.plot(x,[0.6050,0.6738,0.6791,0.7272],'y-v',label='DRH')
ash = plt.plot(x,[0.7561,0.8432,0.7884,0.8480],'r-^',label='ASH')
plt.xticks(x)
plt.ylabel('ASOCT-Cataract')
plt.title('mHR')
plt.legend()
# 2
plt.subplot(2, 3, 2)
lsh = plt.plot(x,[0.1846,0.1020,0.1542,0.1080],'b-v',label='LSH')
dpsh = plt.plot(x,[0.2785,0.1855,0.2235,0.2148],'g-v',label='DPSH')
dsh = plt.plot(x,[0.3583,0.3031,0.4520,0.3349],'k-v',label='DSH')
drh = plt.plot(x,[0.5023,0.5970,0.6060,0.6604],'y-v',label='DRH')
ash = plt.plot(x,[0.7000,0.8133,0.7230,0.8161],'r-^',label='DSH')
plt.xticks(x)
plt.title('mAP')
plt.legend()
# 3
plt.subplot(2, 3, 3)
lsh = plt.plot(x,[0.5789,0.4757,0.5342,0.4570],'b-v',label='LSH')
dpsh = plt.plot(x,[0.6774,0.5794,0.7268,0.6443],'g-v',label='DPSH')
dsh = plt.plot(x,[0.8532,0.8195,0.8106,0.8451],'k-v',label='DSH')
drh = plt.plot(x,[0.8479,0.9214,0.9368,0.9451],'y-v',label='DRH')
ash = plt.plot(x,[0.9563,0.9867,0.9589,0.9819],'r-^',label='ASH')
plt.xticks(x)
plt.title('mRR')
plt.legend()
# 4
plt.subplot(2, 3, 4)
lsh = plt.plot(x,[0.4624,0.4682,0.4629,0.4631],'b-v',label='LSH')
dpsh = plt.plot(x,[0.6188,0.6298,0.6440,0.6240],'g-v',label='DPSH')
dsh = plt.plot(x,[0.6331,0.6367,0.6455,0.6429],'k-v',label='DSH')
drh = plt.plot(x,[0.6392,0.6434,0.6264,0.6177],'y-v',label='DRH')
ash = plt.plot(x,[0.6977,0.6901,0.7209,0.7470],'r-^',label='ASH')
plt.xticks(x)
plt.ylabel('Fundus-iSee')
plt.title('mHR')
plt.legend()
# 5
plt.subplot(2, 3, 5)
lsh = plt.plot(x,[0.3828,0.4091,0.3835,0.3836],'b-v',label='LSH')
dpsh = plt.plot(x,[0.5154,0.5579,0.5512,0.5212],'g-v',label='DPSH')
dsh = plt.plot(x,[0.5399,0.5410,0.5521,0.5414],'k-v',label='DSH')
drh = plt.plot(x,[0.5428,0.5678,0.5273,0.6598],'y-v',label='DRH')
ash = plt.plot(x,[0.6346,0.6280,0.6713,0.7233],'r-^',label='ASH')
plt.xticks(x)
plt.title('mAP')
plt.legend()
# 6
plt.subplot(2, 3, 6)
lsh = plt.plot(x,[0.6455,0.6876,0.6457,0.6456],'b-v',label='LSH')
dpsh = plt.plot(x,[0.8229,0.8601,0.8325,0.8025],'g-v',label='DPSH')
dsh = plt.plot(x,[0.8341,0.8266,0.8318,0.8222],'k-v',label='DSH')
drh = plt.plot(x,[0.8243,0.8625,0.8276,0.8798],'y-v',label='DRH')
ash = plt.plot(x,[0.8707,0.8830,0.9032,0.9525],'r-^',label='ASH')
plt.xticks(x)
plt.title('mRR')
plt.legend()


plt.legend()
plt.show()
